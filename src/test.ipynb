# %%
import time

import problem as p
import threading
for i in range(1000,1300):
    x = p.Problem(f'P{i}')
    time.sleep(0.1)
    print(f'P{i} {x.title}')

p.list()
None
# Out:
# P1000 超级玛丽游戏
# P1001 A+B Problem
# P1002 [NOIP2002 普及组] 过河卒
# P1003 [NOIP2011 提高组] 铺地毯
# P1004 [NOIP2000 提高组] 方格取数
# P1005 [NOIP2007 提高组] 矩阵取数游戏
# P1006 [NOIP2008 提高组] 传纸条
# P1007 独木桥
# P1008 [NOIP1998 普及组] 三连击
# P1009 [NOIP1998 普及组] 阶乘之和
# P1010 [NOIP1998 普及组] 幂次方
# P1011 [NOIP1998 提高组] 车站
# P1012 [NOIP1998 提高组] 拼数
# P1013 [NOIP1998 提高组] 进制位
# P1014 [NOIP1999 普及组] Cantor 表
# P1015 [NOIP1999 普及组] 回文数
# P1016 [NOIP1999 提高组] 旅行家的预算
# P1017 [NOIP2000 提高组] 进制转换
# P1018 [NOIP2000 提高组] 乘积最大
# P1019 [NOIP2000 提高组] 单词接龙
# P1020 [NOIP1999 提高组] 导弹拦截
# P1021 [NOIP1999 提高组] 邮票面值设计
# P1022 [NOIP2000 普及组] 计算器的改良
# P1023 [NOIP2000 普及组] 税收与补贴问题
# P1024 [NOIP2001 提高组] 一元三次方程求解
# P1025 [NOIP2001 提高组] 数的划分
# P1026 [NOIP2001 提高组] 统计单词个数
# P1027 [NOIP2001 提高组] Car 的旅行路线
# P1028 [NOIP2001 普及组] 数的计算
# P1029 [NOIP2001 普及组] 最大公约数和最小公倍数问题
# P1030 [NOIP2001 普及组] 求先序排列
# P1031 [NOIP2002 提高组] 均分纸牌
# P1032 [NOIP2002 提高组] 字串变换
# P1033 [NOIP2002 提高组] 自由落体
# P1034 [NOIP2002 提高组] 矩形覆盖
# P1035 [NOIP2002 普及组] 级数求和
# ...

# %%
import user, utils
sess = utils.Session(utils._cookies)

# sess.captcha(True)
ko114 = user.User(sess, 1435654)
sess.changeLastOnline()

for name, value in vars(ko114).items():
    if name.startswith('_'):
        continue
    if name == 'prize':
        
        print(f'Prizes: ')
        for i in value:
            print(f'\t[{i.contest_name} {i.year}]\t{i.prize}')
        print()
        continue
    print(f'{name}: {value}')
# Out:
# 时间匆匆忙忙就过去了……  || Last Online:  2024-12-21 13:15
# 时间匆匆忙忙就过去了……  || Last Online:  2024-12-23 19:59
# session: <utils.Session object at 0x76b6eb3d1fd0>
# register_time: 2024-08-28 16:27:29
# introduction: [![Page Views Count](https://badges.toozhao.com/badges/01JBNNM90W7KKX1DDWBCHKP4E6/orange.svg)](https://badges.toozhao.com/stats/01JBNNM90W7KKX1DDWBCHKP4E6 "Get your own page views count badge on badges.toozhao.com")
# $$\LaTeX\text{麻烦使用：}\textbf{\color{#8344ad}ko114}\textsf{{\color{#ffffff}\colorbox{#8e44ad}{HOMO}}}$$
# ```plain
# $\textbf{\color{#8344ad}ko114}\textsf{{\color{#ffffff}\colorbox{#8e44ad}{HOMO}}}$
# ```
# ...

# %%
import time
while True:
    sess.changeLastOnline()
    time.sleep(60)
# Out:
# 可互关，要求见  || Last Online:  2024-12-23 20:35
# 可互关，要求见  || Last Online:  2024-12-23 20:37
